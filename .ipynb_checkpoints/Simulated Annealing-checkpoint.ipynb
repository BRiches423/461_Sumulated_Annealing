# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import math 
import random

# %% [markdown]
# # Setting up the variables

# %%
class Anneal:
    def __init__(self, data_link, initial_temp):
        #self.data = np.array([])
        #self.length = 0
        self.goal = 1000
        self.objective = 0
        self.weight = 0
        self.loop_size = 40000
        self.max_changes = 4000
        self.temp = initial_temp
        self.sucessful_changes = 10
        self.annealed_changes = 0
        self.looped = 0
        self.load(data_link)

# %% [markdown]
# # Defining functions for annealing

# %%
class Anneal(Anneal):    
    
    def penalty(self):
        return max(0, ((self.data[:,[2]]*self.data[:,[1]]).sum(axis = 0)[0] - 500)*20)
    
    
    def get_objective(self):
        return self.goal - (self.data[:,[2]]*self.data[:,[0]]).sum(axis = 0)[0] + self.penalty()
    
    
    def invert(self,index):
        self.data[index, 2] = abs(self.data[index, 2]-1) 
        
        
    def prob_accept(self):
        cumulative = math.exp(-(abs(self.objective - self.get_objective()))/self.temp)
        return random.uniform(0,1) <= cumulative

# %% [markdown]
# # Defining data imports

# %%
class Anneal(Anneal):
    
    def load(self, link_name):
        self.data = np.loadtxt(link_name)
        self.length = self.data.shape[0]
        self.data = np.append(self.data,np.repeat(0, self.length).reshape(self.length, 1), axis = 1)
        self.initialize()
    
    def initialize(self):
   
        for i in range(self.length):
            if(random.uniform(0,1) <= 0.05):
                self.data[i, 2] = 1
                
        self.objective = self.get_objective()
        self.weight = (self.data[:,[2]]*self.data[:,[1]]).sum(axis = 0)[0]

# %% [markdown]
# # Defining the Annealing Process

# %%
class Anneal(Anneal):    
    def anneal(self):

        self.sucessful_changes = 0
        self.annealed_changes = 0
        self.looped = 0 
        print()
        for loop in range(self.loop_size):
            self.looped = loop
            index_changed = random.randrange(0, self.length)
            self.invert(index_changed)
            temp_objective = self.get_objective()

            if(temp_objective < self.objective):
                self.objective = temp_objective
                self.sucessful_changes += 1

                if(self.sucessful_changes == self.max_changes):
                    break

            elif(self.prob_accept()):
                self.objective = temp_objective
                self.annealed_changes += 1
                self.sucessful_changes +=1

                if(self.sucessful_changes == self.max_changes):
                    break
            else:
                self.invert(index_changed)

# %% [markdown]
# # Using a loop to control the annealing process

# %%
forge = Anneal('Program2Input.txt', 4000)
stats1 = pd.DataFrame(columns = ['temp', 'objective', 'weight', 'percent_annealed'])
while(forge.sucessful_changes != 0):
    forge.anneal()
    stats1 = pd.concat([stats1, pd.DataFrame({'temp': [forge.temp], 'objective': [forge.objective], 'weight': [(forge.data[:,[2]]*forge.data[:,[1]]).sum(axis = 0)[0]], 'percent_annealed':\
                                             (forge.annealed_changes/(forge.looped - forge.sucessful_changes))})], ignore_index = True)
    forge.temp = forge.temp*0.98

output1 = pd.DataFrame(forge.data, columns = ['objective', 'weight', 'included'])
print((forge.data[:,[2]]*forge.data[:,[1]]).sum(axis = 0)[0])
print((forge.data[:,[2]]*forge.data[:,[0]]).sum(axis = 0)[0])
output1.to_csv('ouput5.txt')
stats1.to_csv('stats5.txt')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [120], in <module>
#       2 stats1 = pd.DataFrame(columns = ['temp', 'objective', 'weight', 'percent_annealed'])
#       3 while(forge.sucessful_changes != 0):
# ----> 4     forge.anneal()
#       5     stats1 = pd.concat([stats1, pd.DataFrame({'temp': [forge.temp], 'objective': [forge.objective], 'weight': [(forge.data[:,[2]]*forge.data[:,[1]]).sum(axis = 0)[0]], 'percent_annealed':\
#       6                                              (forge.annealed_changes/(forge.looped - forge.sucessful_changes))})], ignore_index = True)
#       7     forge.temp = forge.temp*0.98
#
# Input In [103], in Anneal.anneal(self)
#      10 index_changed = random.randrange(0, self.length)
#      11 self.invert(index_changed)
# ---> 12 temp_objective = self.get_objective()
#      14 if(temp_objective < self.objective):
#      15     self.objective = temp_objective
#
# Input In [101], in Anneal.get_objective(self)
#       7 def get_objective(self):
# ----> 8     return self.goal - (self.data[:,[2]]*self.data[:,[0]]).sum(axis = 0)[0] + self.penalty()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\_methods.py:46, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      42 def _amin(a, axis=None, out=None, keepdims=False,
#      43           initial=_NoValue, where=True):
#      44     return umr_minimum(a, axis, None, out, keepdims, initial, where)
# ---> 46 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      47          initial=_NoValue, where=True):
#      48     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      50 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#      51           initial=_NoValue, where=True):
#
# KeyboardInterrupt:

# %%
print(output1)
# Out:
#      objective  weight  included
# 0          4.5     5.1       1.0
# 1          6.4    14.9       0.0
# 2          3.2     1.1       1.0
# 3          9.1     3.9       1.0
# 4          8.3    10.2       0.0
# ..         ...     ...       ...
# 395        5.6     4.0       1.0
# 396        2.2     6.7       0.0
# 397        6.7     9.8       0.0
# 398       10.0    16.6       0.0
# 399        1.3     1.0       1.0
#
# [400 rows x 3 columns]

# %%
print(forge.data[:,[2]]*se.data[:,[1]]).sum(axis = 0)[0])
# Out:
#         temp objective  weight percent_annealed
# 0       4000   30734.9  2035.3        18.468468
# 1       3900   27583.0  1875.4        18.462963
# 2       3800   33467.9  2175.6         18.62963
# 3       3700   33713.8  2186.3        18.357798
# 4       3600   32549.8  2124.5         15.59375
# ..       ...       ...     ...              ...
# 71  0.228768     300.4   499.8           0.0001
# 72  0.205891     300.4   499.8         0.000075
# 73  0.185302     300.4   499.8         0.000025
# 74  0.166772     300.4   499.8         0.000025
# 75  0.150095     300.4   499.8              0.0
#
# [76 rows x 4 columns]

# %%
#output1 = geometric
#output2 = exponential geometric
#output3 = linear kinov
#output4 = geometric with .9
#output5 = geometric with .95
'''
   if(forge.temp > 100):
        forge.temp = forge.temp - 100
    elif(forge.temp > 10):
        forge.temp = forge.temp -10
    elif(forge.temp > 1):
        forge.temp = forge.temp - 1
    else:
        forge.temp *= .9
'''
